# %% [markdown]
# #Heading

# %% [markdown]
# # Headgin
# ## Heading2
# ### Heading 3
# #### Heading

# %%
# !python --version

# %%
# !whoami

# %%
# !dir

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Opening the jupyter notebook

# %% [markdown]
# Anaconda navigator ---> launch
# open anaconda prompt ---> jupyter notebook
# open jupyter notebook

# %% [markdown]
# # comment in python

# %%
#this is coomment

# %%
'''
this is multiline comment
'''

# %% [markdown]
# ## Keywords,identifers and variables in Python

# %%
## Keywords are used for specific purpose

False  ----> It is a keyword
false  ----> It is not a keyword

# %%
false
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-b73d74fcede9> in <module>
# ----> 1 false
#
# NameError: name 'false' is not defined

# %%
False

# %% [markdown]
# # Importing keyword

# %%
import keyword

# %%
#keyword +. +tab will give all unctions
keyword.kwlist
#afergetting specific function then we can press shift + tab then we will get syntax

# %%
# Identifers --->User defined names to variables ,class and others
# variables ---> They act as memory holders and store the entries values and change the values during the exeution of program

# Rules for assigning names to identifer:
    cannot be keyword
    cannot start with number
    cannot have special symbol
    names cannot have spaces
    case sensitive

# %%
keyword.iskeyword('True')
keyword.iskeyword('try')
# Out:
# True

# %%
keyword.iskeyword('except')
# Out:
# True

# %%
keyword.iskeyword('excpt')
# Out:
# False

# %% [markdown]
# # Data types
#
#  1. number
#    a. integers
#    b. float
#    c. complex
#  2. string
#  3. Boolen
#  4. List
#  5. Set
#  6. Tuple
#  7. Dict

# %%
# List:
   Allows heterogenous data
   Index starts from 0
   List elements are mutable

# %% [markdown]
# # List operations

# %%
lst = [12,45,34,567,345,678]

# %%
lst.sort()
print(lst)
# Out:
# [12, 34, 45, 345, 567, 678]

# %%
lst.sort(reverse=True)
print(lst)
# Out:
# [678, 567, 345, 45, 34, 12]

# %%
lst.sort?

# %%
lst.append(9)
# append will append at last

# %%
lst
# Out:
# [678, 567, 345, 45, 34, 12, 9]

# %%
lst.count(9)
# no.of occuerance of an value
# Out:
# 1

# %%
lst.extend([35,235,2456,7556])
lst
# Out:
# [678, 567, 345, 45, 34, 12, 9, 35, 235, 2456, 7556]

# %%
a = lst.pop(3)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-82-e8e27bee4489> in <module>
# ----> 1 a = lst.pop(34)
#
# IndexError: pop index out of range

# %%
a
# Out:
# 45

# %%
lst
# Out:
# [678, 567, 345, 34, 12, 9, 35, 235, 2456, 7556]

# %%
c = lst.remove(34)

# %%
lst
# Out:
# [34,
#  24,
#  24,
#  34,
#  24,
#  34,
#  34,
#  2,
#  2,
#  678,
#  567,
#  345,
#  9,
#  35,
#  235,
#  2456,
#  7556,
#  34,
#  45,
#  [323, 4305]]

# %%
c

# %%
##  Pop can remove a value from list and can save that value in another variable 
##  whereas remove cannot store a value into variable when we remove from list

# %%
lst.extend([34,45])

# %%
lst
# Out:
# [678, 567, 345, 9, 35, 235, 2456, 7556, 34, 45]

# %%
lst.extend([[323,4305]])

# %%
lst
# Out:
# [678, 567, 345, 9, 35, 235, 2456, 7556, 34, 45, [323, 4305]]

# %%
## List slicing

lst[2]
# Out:
# 345

# %%
lst[2:]
# Out:
# [345, 9, 35, 235, 2456, 7556, 34, 45, [323, 4305]]

# %%
lst[2:4]
# Out:
# [345, 9]

# %%
lst[2:7]
# Out:
# [345, 9, 35, 235, 2456]

# %%
lst
# Out:
# [678, 567, 345, 9, 35, 235, 2456, 7556, 34, 45, [323, 4305]]

# %%
lst[0:4]
# Out:
# [678, 567, 345, 9]

# %%
lst[:0] = [2]
lst
# Out:
# [2, 2, 678, 567, 345, 9, 35, 235, 2456, 7556, 34, 45, [323, 4305]]

# %%
lst[:0] = [34,24]
lst
# Out:
# [34,
#  24,
#  34,
#  24,
#  24,
#  34,
#  2,
#  2,
#  678,
#  567,
#  345,
#  9,
#  35,
#  235,
#  2456,
#  7556,
#  34,
#  45,
#  [323, 4305]]

# %%
lst[-1]
# Out:
# [323, 4305]

# %%
lst[:-1]
# Out:
# [34, 24, 34, 24, 24, 34, 2, 2, 678, 567, 345, 9, 35, 235, 2456, 7556, 34, 45]

# %%
lst
# Out:
# [24, 2, 2, 678, 567, 345, 9, 35, 235, 2456, 7556, 34, 45, [323, 4305]]

# %%
lst[-2:-1]
# Out:
# [45]

# %%
lst[-2]
# Out:
# 45

# %%
lst.remove(34)

# %%
lst
# Out:
# [24, 2, 2, 678, 567, 345, 9, 35, 235, 2456, 7556, 34, 45, [323, 4305]]

# %%
lst.insert(5,6)

# %%
lst
# Out:
# [24, 2, 2, 678, 567, 6, 345, 9, 35, 235, 2456, 7556, 34, 45, [323, 4305]]

# %%
lst.insert(5,30)
lst
# Out:
# [24, 2, 2, 678, 567, 30, 6, 345, 9, 35, 235, 2456, 7556, 34, 45, [323, 4305]]
