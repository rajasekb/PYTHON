# %%
import pandas

# %%
df = pd.read_csv(r"C:\Users\Lenovo\Desktop\Data_Science\src\can")
df.head(3)
# Out:
#    year  per_capita_income
# 0  1970        3399.299037
# 1  1971        3768.297935
# 2  1972        4251.175484

# %%
df['year'].value.counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-1ddeabbe361a> in <module>
# ----> 1 df['year'].value.counts()
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'value'

# %%
df.dtypes
# Out:
# year                   int64
# per_capita_income    float64
# dtype: object

# %%
df['year1']=[i*i for i in df['year']]

# %%
df.head()
# Out:
#    year  per_capita_income    year1
# 0  1970        3399.299037  3880900
# 1  1971        3768.297935  3884841
# 2  1972        4251.175484  3888784
# 3  1973        4804.463248  3892729
# 4  1974        5576.514583  3896676

# %%
sq=lambda sq:df["Meal Price"]*df["Meal Price"]
df['Square']=sq(df['Square'])
df.head()

# %%
df['year2']= list(map(lambda x:x*x,df['year']))

# %%
df.head(3)
# Out:
#    year  per_capita_income    year1    year2
# 0  1970        3399.299037  3880900  3880900
# 1  1971        3768.297935  3884841  3884841
# 2  1972        4251.175484  3888784  3888784

# %%
def square(x):
    return x*x
df['year3'] = df['year'].apply(square)

# %%
df
# Out:
#     year  per_capita_income    year1    year2    year3
# 0   1970        3399.299037  3880900  3880900  3880900
# 1   1971        3768.297935  3884841  3884841  3884841
# 2   1972        4251.175484  3888784  3888784  3888784
# 3   1973        4804.463248  3892729  3892729  3892729
# 4   1974        5576.514583  3896676  3896676  3896676
# 5   1975        5998.144346  3900625  3900625  3900625
# 6   1976        7062.131392  3904576  3904576  3904576
# 7   1977        7100.126170  3908529  3908529  3908529
# 8   1978        7247.967035  3912484  3912484  3912484
# 9   1979        7602.912681  3916441  3916441  3916441
# 10  1980        8355.968120  3920400  3920400  3920400
# 11  1981        9434.390652  3924361  3924361  3924361
# 12  1982        9619.438377  3928324  3928324  3928324
# 13  1983       10416.536590  3932289  3932289  3932289
# 14  1984       10790.328720  3936256  3936256  3936256
# 15  1985       11018.955850  3940225  3940225  3940225
# ...

# %%
df['year_lambda'] = df['year'].apply(lambda z:z*z)

# %%
df.head()
# Out:
#    year  per_capita_income    year1    year2    year3  year_lambda
# 0  1970        3399.299037  3880900  3880900  3880900      3880900
# 1  1971        3768.297935  3884841  3884841  3884841      3884841
# 2  1972        4251.175484  3888784  3888784  3888784      3888784
# 3  1973        4804.463248  3892729  3892729  3892729      3892729
# 4  1974        5576.514583  3896676  3896676  3896676      3896676

# %%
def fun2(string1,string2):
    return string1+string2

# %%
df['new_yar'] = df.apply(lambda x,fun2

# %%
df.loc[1,'year'] = 'string'

# %%
df.dtypes
# Out:
# year                  object
# per_capita_income    float64
# year1                  int64
# year2                  int64
# year3                  int64
# year_lambda            int64
# dtype: object

# %%
df
# Out:
#       year  per_capita_income    year1    year2    year3  year_lambda
# 0     1970        3399.299037  3880900  3880900  3880900      3880900
# 1   string        3768.297935  3884841  3884841  3884841      3884841
# 2     1972        4251.175484  3888784  3888784  3888784      3888784
# 3     1973        4804.463248  3892729  3892729  3892729      3892729
# 4     1974        5576.514583  3896676  3896676  3896676      3896676
# 5     1975        5998.144346  3900625  3900625  3900625      3900625
# 6     1976        7062.131392  3904576  3904576  3904576      3904576
# 7     1977        7100.126170  3908529  3908529  3908529      3908529
# 8     1978        7247.967035  3912484  3912484  3912484      3912484
# 9     1979        7602.912681  3916441  3916441  3916441      3916441
# 10    1980        8355.968120  3920400  3920400  3920400      3920400
# 11    1981        9434.390652  3924361  3924361  3924361      3924361
# ...

# %%
df.tail()
# Out:
#     year  per_capita_income    year1    year2    year3  year_lambda
# 42  2012        42665.25597  4048144  4048144  4048144      4048144
# 43  2013        42676.46837  4052169  4052169  4052169      4052169
# 44  2014        41039.89360  4056196  4056196  4056196      4056196
# 45  2015        35175.18898  4060225  4060225  4060225      4060225
# 46  2016        34229.19363  4064256  4064256  4064256      4064256
