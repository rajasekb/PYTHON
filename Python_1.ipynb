# %% [markdown]
# # Data Science

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# will make at as header
copy image and run will the shell

# %%
# !python --version
# Out:
# Python 3.7.6

# %%
# !whoami
# Out:
# desktop-94bnppp\lenovo

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is C263-980F
#
#  Directory of C:\Users\Lenovo\Desktop\Data_Science\Inceptez\December\PYTHON
#
# 12/05/2020  05:37 PM    <DIR>          .
# 12/05/2020  05:37 PM    <DIR>          ..
# 12/05/2020  05:37 PM    <DIR>          .ipynb_checkpoints
# 12/05/2020  05:35 PM           166,890 Python_1.ipynb
#                1 File(s)        166,890 bytes
#                3 Dir(s)  18,715,602,944 bytes free

# %% [markdown]
# ## This is my first program

# %%
print("Hello World")
# Out:
# Hello World

# %%
'''
what ever i write here are comments
'''
# Out:
# '\nwhat ever i write here are comments\n'

# %% [markdown]
# #### Keywords is special word and has specific purpose and all keys are highlighted in different color
# #### Identifers are user defined names to any variable/function/class/module
# #### variables are memory holders who values will change during the excuetion of a program
# ### Identifier rules:
#       Cannot be keyword
#       Cannot start with number
#       cannot have spaces inbetween
#       it should not contain alphabets
#       No special charaters @,!,

# %%
import keyword
keyword.kwlist

# %% [markdown]
# # Type conversion

# %%
a=10
print(a)
# Out:
# 10

# %%
str(a)
print(a)
# Out:
# 10

# %%
a='10'
int(a)
# Out:
# 10

# %%
s='Rajasekhar'
list(s)
# Out:
# ['R', 'a', 'j', 'a', 's', 'e', 'k', 'h', 'a', 'r']

# %%
tuple(s)
# Out:
# ('R', 'a', 'j', 'a', 's', 'e', 'k', 'h', 'a', 'r')

# %%
lst = [[1,2],[3,4],[5,6]]

# %%
lst[0][0]
# Out:
# 1

# %%
lstt = [[1,2],[3,4],[5,6],["a",["gr","ab"]]]

# %%
lstt[3][1][0]
# Out:
# 'gr'

# %%
6-5.7
# Out:
# 0.2999999999999998

# %%
round(6-5.7,2)
# Out:
# 0.3

# %%
texxt = "Rajasekhar"

# %%
texxt[2]
# Out:
# 'j'

# %%
texxt[4]
# Out:
# 's'

# %%
texxt[0] = 'SC'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-d9a7f5518d84> in <module>
# ----> 1 texxt[0] = 'SC'
#
# TypeError: 'str' object does not support item assignment

# %%
texxt[0:3]
# Out:
# 'Raj'

# %%
texxt[:3]
# Out:
# 'Raj'

# %%
texxt[4:]
# Out:
# 'sekhar'

# %%
ne = "let's learn python"

# %%
ne
# Out:
# "let's learn python"

# %%
nee = 'let\n'

# %% [markdown]
# # List

# %%
lst=['Raj','Sravanthi','Joshwik','Farm']

# %%
lst[0]
# Out:
# 'Raj'

# %%
lst[0:2]
# Out:
# ['Raj', 'Sravatnhi']

# %%
lst[:3]
# Out:
# ['Raj', 'Sravatnhi', 'Joshwik']

# %%
lst[2:]
# Out:
# ['Joshwik', 'Farm']

# %%
lst[1:3]
# Out:
# ['Sravatnhi', 'Joshwik']

# %%
lst.append("Mangoes")

# %%
lst
# Out:
# ['Raj', 'Sravatnhi', 'Joshwik', 'Farm', 'Mangoes']

# %%
lst.append("chips")

# %%
lst
# Out:
# ['Raj', 'Sravanthi', 'Joshwik', 'Farm', 'Mangoes', 'chips']

# %%
lst.insert(3,"Heroo")

# %%
lst
# Out:
# ['Raj', 'Sravanthi', 'Joshwik', 'Heroo', 'Farm', 'Mangoes', 'chips']

# %%
lst[5]="Vegetables"

# %%
lst
# Out:
# ['Raj', 'Sravanthi', 'Joshwik', 'Heroo', 'Farm', 'Vegetables', 'chips']

# %%
lst[-1]
# Out:
# 'Vegetables'

# %%
lst[-3:]
# Out:
# ['Farm', 'Mangoes', 'Vegetables']

# %%
lst[-3:5]
# Out:
# ['Farm', 'Mangoes']

# %%
food=["bread","butter","jam"]
bathroom=["sampoo","soap","brush"]

# %%
items=food+bathroom

# %%
items
# Out:
# ['bread', 'butter', 'jam', 'sampoo', 'soap', 'brush']

# %%
len(lst)
# Out:
# 7

# %%
lst[0:len(lst)]
# Out:
# ['Raj', 'Sravanthi', 'Joshwik', 'Heroo', 'Farm', 'Vegetables', 'chips']

# %%
'Raj' in lst
# Out:
# True

# %%
"raj".lower() in lst.lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-5ba90033492a> in <module>
# ----> 1 "raj".lower() in lst.lower()
#
# AttributeError: 'list' object has no attribute 'lower'

# %%
"raj".lower() in lst
# Out:
# False
