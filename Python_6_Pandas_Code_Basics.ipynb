# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ted = pd.read_csv(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\SOURCE\CODE_Basics\1nyc_weather.csv')

# %%
ted.head(1)
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
#
#    WindDirDegrees
# 0             281

# %%
ted['Temperature'].max()
# Out:
# 50

# %%
ted[['Temperature','DewPoint']].head(1)
# Out:
#    Temperature  DewPoint
# 0           38        23

# %%
ted.loc[ted['Temperature'] >32].head(2)
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
#
#    WindDirDegrees
# 0             281
# 1             275

# %%
ted['EST'][ted['Events']=='Rain'].head(2)
# Out:
# 0    1/1/2016
# 1    1/2/2016
# Name: EST, dtype: object

# %%
ted.loc[ted['Events'] =='Rain'] ['EST'].head(2)
# Out:
# 0    1/1/2016
# 1    1/2/2016
# Name: EST, dtype: object

# %%
ted.loc[ted['Events'].str.contains('rain',case=False)].head(2)
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5   Rain
# 1               10           7.0               0           3   Rain
#
#    WindDirDegrees
# 0             281
# 1             275

# %%
ted['WindSpeedMPH'].mean()
# Out:
# 6.225806451612903

# %% [markdown]
# ##### process of data cleaning is called as data munging or data wrangling

# %%
ted.fillna(0,inplace=True)

# %% [markdown]
# ## Data Frame

# %%
ted2 = pd.read_csv(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\SOURCE\CODE_Basics\2weather_data.csv')

# %%
ted2
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
dat = {
    
    'day':['1/1/2017','1/2/2017','1/3/2017'],
    'temperature':[32,34,56],
    'windspeed':[6,7,3],
    'event':['Rain','Sunny','Rain']
} 

df=pd.DataFrame(dat)

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           34          7  Sunny
# 2  1/3/2017           56          3   Rain

# %%
ted2.shape
# Out:
# (6, 4)

# %%
rows,columns=ted2.shape

# %%
rows
# Out:
# 6

# %%
ted2.head(4)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow

# %%
ted2.tail(2)
# Out:
#         day  temperature  windspeed  event
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
# printing row 2 to 4
ted2[2:5]
# Out:
#         day  temperature  windspeed event
# 2  1/3/2017           28          2  Snow
# 3  1/4/2017           24          7  Snow
# 4  1/5/2017           32          4  Rain

# %%
#printing columns

ted2.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
ted2.day
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
ted2[['day','event']]
# Out:
#         day  event
# 0  1/1/2017   Rain
# 1  1/2/2017  Sunny
# 2  1/3/2017   Snow
# 3  1/4/2017   Snow
# 4  1/5/2017   Rain
# 5  1/6/2017  Sunny

# %%
type(ted2)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### Columns in the dataframe are type series

# %%
ted2[['day']].max()
# Out:
# day    1/6/2017
# dtype: object

# %%
ted2.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
ted2.loc[ted2['temperature'] > 32]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny

# %%
ted2[ted2.temperature>=32]
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 4  1/5/2017           32          4   Rain

# %%
ted2[ted2['temperature'] ==ted2['temperature'].max()][['day','windspeed']]
# Out:
#         day  windspeed
# 1  1/2/2017          7

# %%
ted2
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
# changing the index. Replacing index with another column
ted2.set_index('day',inplace=True)

# %%
ted2.loc['1/3/2017']
# Out:
# temperature      28
# windspeed         2
# event          Snow
# Name: 1/3/2017, dtype: object

# %%
# Resetting the index

ted2.reset_index(inplace=True)

# %%
ted2
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
ted2.set_index('event',inplace=True)

# %%
ted2.loc['Snow']
# Out:
#             day  temperature  windspeed
# event
# Snow   1/3/2017           28          2
# Snow   1/4/2017           24          7

# %% [markdown]
# ## Different ways of creating Dataframe

# %%
# using list of tuple
datt = [
    ('1/1/2017','Raj','HYD'),
    ('1/3/2017','Josh','BNG'),
    ('1/7/2017','Sravs','Pak')   
]

# %%
df =pd.DataFrame(datt,columns=['day','Name','City'])
df
# Out:
#         day   Name City
# 0  1/1/2017    Raj  HYD
# 1  1/3/2017   Josh  BNG
# 2  1/7/2017  Sravs  Pak

# %%
# Using dictonary

dat = {
    
    'day':['1/1/2017','1/2/2017','1/3/2017'],
    'temperature':[32,34,56],
    'windspeed':[6,7,3],
    'event':['Rain','Sunny','Rain']
} 

df1=pd.DataFrame(dat)
df1
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           34          7  Sunny
# 2  1/3/2017           56          3   Rain

# %%
# Using list of dictonaries

datt = [
    {'day':'1/1/2017','Name':'Raj','City':'TPTY'},
    {'day':'1/2/2017','Name':'Ammu','City':'Rjy'}
    
]

# %%
pd.DataFrame(datt)
# Out:
#         day  Name  City
# 0  1/1/2017   Raj  TPTY
# 1  1/2/2017  Ammu   Rjy

# %% [markdown]
# ### Reading files

# %%
## Skiprows

dff = pd.read_csv(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\SOURCE\CODE_Basics\3stock_data.csv',skiprows=1)
dff

                     or
dff = pd.read_csv(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\SOURCE\CODE_Basics\3stock_data.csv',header=1)
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
## Manually passing the header
dff_names = pd.read_csv(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\SOURCE\CODE_Basics\3stock_data - Copy.csv',skiprows=2,
                        names=['Tickers','EPS','Revenue','Price','People'])

# %%
dff_names
# Out:
#   Tickers            EPS  Revenue Price         People
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
# wanted to read only few rows then

dff_rows = pd.read_csv(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\SOURCE\CODE_Basics\3stock_data.csv',skiprows=1,nrows=3)
dff_rows
# Out:
#   tickers    eps  revenue  price      people
# 0   GOOGL  27.82       87    845  larry page
# 1     WMT   4.61      484     65        n.a.
# 2    MSFT  -1.00       85     64  bill gates

# %%
# replacing some values with NaN

dff_nan = pd.read_csv(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\SOURCE\CODE_Basics\3stock_data.csv',skiprows=1,
                      na_values=['n.a.','not available'])

# %%
dff_nan
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82       87   845.0     larry page
# 1     WMT   4.61      484    65.0            NaN
# 2    MSFT  -1.00       85    64.0     bill gates
# 3    RIL     NaN       50  1023.0  mukesh ambani
# 4    TATA   5.60       -1     NaN     ratan tata

# %%
## Replacing only specific columns with NaN
dff_spec_coll = pd.read_csv(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\SOURCE\CODE_Basics\3stock_data.csv',
                            skiprows=1,na_values={
                                'eps':['n.a.','not available'],
                                'revenue':['n.a.','not available',-1],
                                'people':['n.a.','not available'],
                                'price':['n.a.','not available']
                                       })

# %%
dff_spec_coll
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82     87.0   845.0     larry page
# 1     WMT   4.61    484.0    65.0            NaN
# 2    MSFT  -1.00     85.0    64.0     bill gates
# 3    RIL     NaN     50.0  1023.0  mukesh ambani
# 4    TATA   5.60      NaN     NaN     ratan tata

# %%
#saving only specific columns

dff_spec_coll.to_csv(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\TARGET\Specific_col.csv',columns=['tickers','eps'])

# %%
# saving without header

dff_spec_coll.to_csv(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\TARGET\No_header.csv',columns=['tickers','eps'],
                     header=False)

# %% [markdown]
# ## Reading excel

# %%
# reading excel from a sheet

exc = pd.read_excel(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\SOURCE\CODE_Basics\3stock_data_excel.xlsx','Data')

# %%
exc
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
## replacing n.a to some name in people column
def convert_people(cell):
    if cell == 'n.a.':
        return 'Sam Waltom'
    else:
        return cell

# %%
def eps_converter(cell):
    if cell == 'not available':
        return 'NoT_Provided'

# %%
## Using function while reading a file ----> CONVERTERS
exc = pd.read_excel(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\SOURCE\CODE_Basics\3stock_data_excel.xlsx',
                    'Data',converters ={
                        'people':convert_people,
                        'eps':eps_converter
                    })

# %%
exc
# Out:
#   tickers           eps  revenue price         people
# 0   GOOGL          None       87   845     larry page
# 1     WMT          None      484    65     Sam Waltom
# 2    MSFT          None       85    64     bill gates
# 3    RIL   NoT_Provided       50  1023  mukesh ambani
# 4    TATA          None       -1  n.a.     ratan tata

# %% [markdown]
# ### Writing excel

# %%
exc.to_excel(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\TARGET\new.xlsx','New_Sheet')
                    or
exc.to_excel(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\TARGET\new1.xlsx',sheet_name='New_Sheet1')

# %%
## Specifying the start rows and columns in excel

exc.to_excel(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\TARGET\new1.xlsx',sheet_name='New_Sheet1',
            startrow=3,startcol=3,index=False)

# %%
## writing multiple dataframes to different sheets in same excel

dff_spec_coll,exc

with pd.ExcelWriter(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\TARGET\Multiple_sheets.xlsx') as writer:
    dff_spec_coll.to_excel(writer,sheet_name='specific_column',index=False,startrow=3,startcol=3)
    exc.to_excel(writer,sheet_name='excel_sheet')

# %% [markdown]
# ## Handling Missing and Null values

# %%
filna = pd.read_csv(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\SOURCE\CODE_Basics\4weather_data.csv')
filna
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
type(filna.day[0])
# Out:
# str

# %%
## Converting date column which is in string to date columns

filna = pd.read_csv(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\SOURCE\CODE_Basics\4weather_data.csv',parse_dates=['day'])

# %%
type(filna.day[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
filna
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
filna.set_index('day',inplace=True)

# %%
filna
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_filna = filna.fillna(0)
new_filna
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          0.0        9.0   Sunny
# 2017-01-05         28.0        0.0    Snow
# 2017-01-06          0.0        7.0       0
# 2017-01-07         32.0        0.0    Rain
# 2017-01-08          0.0        0.0   Sunny
# 2017-01-09          0.0        0.0       0
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
newfilna = filna.fillna({
    'temperature':0,
    'windspeed':0,
    'event':'No_Event'
    
})

# %%
newfilna
# Out:
#             temperature  windspeed     event
# day
# 2017-01-01         32.0        6.0      Rain
# 2017-01-04          0.0        9.0     Sunny
# 2017-01-05         28.0        0.0      Snow
# 2017-01-06          0.0        7.0  No_Event
# 2017-01-07         32.0        0.0      Rain
# 2017-01-08          0.0        0.0     Sunny
# 2017-01-09          0.0        0.0  No_Event
# 2017-01-10         34.0        8.0    Cloudy
# 2017-01-11         40.0       12.0     Sunny

# %%
#filling the na with pervious days value

newfilna = filna.fillna(method='ffill')

# %%
newfilna
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         32.0        9.0   Sunny
# 2017-01-05         28.0        9.0    Snow
# 2017-01-06         28.0        7.0    Snow
# 2017-01-07         32.0        7.0    Rain
# 2017-01-08         32.0        7.0   Sunny
# 2017-01-09         32.0        7.0   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
# copying next days values
newfilna = filna.fillna(method='bfill')

# %%
newfilna
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         28.0        9.0   Sunny
# 2017-01-05         28.0        7.0    Snow
# 2017-01-06         32.0        7.0    Rain
# 2017-01-07         32.0        8.0    Rain
# 2017-01-08         34.0        8.0   Sunny
# 2017-01-09         34.0        8.0  Cloudy
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# # axis { 0 ---> index and 1 ---> Columns}

# %%
# It will fill the data horizontally
newfilna = filna.fillna(method='bfill',axis='columns')

# %%
newfilna
# Out:
#            temperature windspeed   event
# day
# 2017-01-01          32         6    Rain
# 2017-01-04           9         9   Sunny
# 2017-01-05          28      Snow    Snow
# 2017-01-06           7         7     NaN
# 2017-01-07          32      Rain    Rain
# 2017-01-08       Sunny     Sunny   Sunny
# 2017-01-09         NaN       NaN     NaN
# 2017-01-10          34         8  Cloudy
# 2017-01-11          40        12   Sunny

# %%
filna
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
# Limit ---> it will specify till what level it should be filles
newfilna = filna.fillna(method='bfill',limit =1)
newfilna

# for 2017-01-08 temparture is null as the we specified limit =1
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         28.0        9.0   Sunny
# 2017-01-05         28.0        7.0    Snow
# 2017-01-06         32.0        7.0    Rain
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09         34.0        8.0  Cloudy
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# ##### Interpolate ---> it takes the average for the numeric columns.There are different methods in interpolate but by default it takes linear

# %%
newfilna = filna.interpolate()
newfilna
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-04    30.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %%
newfilna = filna.interpolate(method='time')
newfilna
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-04    29.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %%
## We can drop all the rows which has null values

newfilna = filna.dropna()
newfilna
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
## drop only if all the values are na

newfilna=filna.dropna(how='all')

# %%
newfilna
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
## It will delete all the rows which has minimum of two values
newfilna=filna.dropna(thresh=2)
newfilna
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-07         32.0        NaN    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
dt = pd.date_range('2017-01-01','2017-01-11')
idx = pd.DatetimeIndex(dt)
filna.reindex(idx)
# Out:
#             temperature  windspeed   event
# 2017-01-01         32.0        6.0    Rain
# 2017-01-02          NaN        NaN     NaN
# 2017-01-03          NaN        NaN     NaN
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# # Handling null values

# %%
handling_nulls = pd.read_csv(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\SOURCE\CODE_Basics\5weather_data.csv')
handling_nulls
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %%
new_handling_nulls = handling_nulls.replace(-99999,np.NaN)
new_handling_nulls
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0      0
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %%
new_handling_nulls = handling_nulls.replace([-99999,'Rain'],np.NaN)
new_handling_nulls
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0    NaN
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0      0
# 4  1/5/2017         32.0        NaN    NaN
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %%
new_handling_nulls = handling_nulls.replace({
    
    -99999:'Raj',
    'Rain':'Sravanathi'
})

new_handling_nulls
# Out:
#         day temperature windspeed       event
# 0  1/1/2017          32         6  Sravanathi
# 1  1/2/2017         Raj         7       Sunny
# 2  1/3/2017          28       Raj        Snow
# 3  1/4/2017         Raj         7           0
# 4  1/5/2017          32       Raj  Sravanathi
# 5  1/6/2017          31         2       Sunny
# 6  1/6/2017          34         5           0

# %%
# replacing values based on specific columns
#handling_nulls



new_df = handling_nulls.replace({
        'temperature': -99999,
        'windspeed': -99999,
        'event': '0'
    }, 'Rajasekhar')
new_df
# Out:
#         day temperature   windspeed       event
# 0  1/1/2017          32           6        Rain
# 1  1/2/2017  Rajasekhar           7       Sunny
# 2  1/3/2017          28  Rajasekhar        Snow
# 3  1/4/2017  Rajasekhar           7  Rajasekhar
# 4  1/5/2017          32  Rajasekhar        Rain
# 5  1/6/2017          31           2       Sunny
# 6  1/6/2017          34           5  Rajasekhar

# %%
# replacing which can be used

neww_df= handling_nulls.replace({
    -99999:np.NaN,
    'Snow':'Breeze'
})

neww_df
# Out:
#         day  temperature  windspeed   event
# 0  1/1/2017         32.0        6.0    Rain
# 1  1/2/2017          NaN        7.0   Sunny
# 2  1/3/2017         28.0        NaN  Breeze
# 3  1/4/2017          NaN        7.0       0
# 4  1/5/2017         32.0        NaN    Rain
# 5  1/6/2017         31.0        2.0   Sunny
# 6  1/6/2017         34.0        5.0       0

# %%
new_df = handling_nulls.replace({
        'temperature': -99999,
        'windspeed': -99999,
        'event': '0'
    }, '-99 MPH')
new_df
# Out:
#         day temperature windspeed    event
# 0  1/1/2017          32         6     Rain
# 1  1/2/2017     -99 MPH         7    Sunny
# 2  1/3/2017          28   -99 MPH     Snow
# 3  1/4/2017     -99 MPH         7  -99 MPH
# 4  1/5/2017          32   -99 MPH     Rain
# 5  1/6/2017          31         2    Sunny
# 6  1/6/2017          34         5  -99 MPH

# %%
#chopping MPH from above example

dfg = new_df.replace({
    'temperature':'[A-Za-z]',
    'windspeed':'[A-Za-z]',
},'',regex=True)
dfg
# Out:
#         day temperature windspeed    event
# 0  1/1/2017          32         6     Rain
# 1  1/2/2017        -99          7    Sunny
# 2  1/3/2017          28      -99      Snow
# 3  1/4/2017        -99          7  -99 MPH
# 4  1/5/2017          32      -99      Rain
# 5  1/6/2017          31         2    Sunny
# 6  1/6/2017          34         5  -99 MPH

# %% [markdown]
# ### Pandas group by function

# %%
grp_by = pd.read_csv(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\SOURCE\CODE_Basics\6weather_by_cities.csv')
grp_by
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
g = grp_by.groupby(["city","event"]).sum()
g
# Out:
#                  temperature  windspeed
# city     event
# mumbai   Fog             172         27
#          Rain             92          5
#          Sunny            90          5
# new york Rain             32          6
#          Snow             28         12
#          Sunny            69         14
# paris    Cloudy          146         31
#          Sunny            45         20

# %%
for city, event,data in g:
    print("city:",city)
    print("\n")
    print("data:",data)
    print(event)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-177-b10901221025> in <module>
# ----> 1 for city, event,data in g:
#       2     print("city:",city)
#       3     print("\n")
#       4     print("data:",data)
#       5     print(event)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
g.get_group('mumbai')
# Out:
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain

# %%
g.max()
# Out:
#                day  temperature  windspeed  event
# city
# mumbai    1/4/2017           92         15  Sunny
# new york  1/4/2017           36         12  Sunny
# paris     1/4/2017           54         20  Sunny

# %%
g.mean()
# Out:
#           temperature  windspeed
# city
# mumbai          88.50       9.25
# new york        32.25       8.00
# paris           47.75      12.75

# %%
g.describe()
# Out:
#          temperature                                                   \
#                count   mean       std   min    25%   50%    75%   max
# city
# mumbai           4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york         4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0
# paris            4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0
#
#          windspeed
#              count   mean       std  min   25%   50%    75%   max
# city
# mumbai         4.0   9.25  5.057997  5.0  5.00   8.5  12.75  15.0
# new york       4.0   8.00  2.708013  6.0  6.75   7.0   8.25  12.0
# paris          4.0  12.75  5.251984  8.0  9.50  11.5  14.75  20.0

# %%
# %matplotlib inline
g.plot()
# Out:
# city
# mumbai      AxesSubplot(0.125,0.125;0.775x0.755)
# new york    AxesSubplot(0.125,0.125;0.775x0.755)
# paris       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# ## Concat operation

# %%
india_wea = pd.DataFrame({
    'city':['Hyd','Chennai','Bangalore'],
    'Temp':[32,40,28],
    'Humidity':[80,60,70]
    
})

# %%
india_wea
# Out:
#         city  Temp  Humidity
# 0        Hyd    32        80
# 1    Chennai    40        60
# 2  Bangalore    28        70

# %%
us_wea = pd.DataFrame({
    'city':['New_york','Chicago','Oralndo'],
    'Temp':[22,18,26],
    'Humidity':[56,59,78]
    
})

# %%
us_wea
# Out:
#        city  Temp  Humidity
# 0  New_york    22        56
# 1   Chicago    18        59
# 2   Oralndo    26        78

# %%
con = pd.concat([india_wea,us_wea])
con
# Out:
#         city  Temp  Humidity
# 0        Hyd    32        80
# 1    Chennai    40        60
# 2  Bangalore    28        70
# 0   New_york    22        56
# 1    Chicago    18        59
# 2    Oralndo    26        78

# %%
con1 = pd.concat([india_wea,us_wea],ignore_index=True)
con1
# Out:
#         city  Temp  Humidity
# 0        Hyd    32        80
# 1    Chennai    40        60
# 2  Bangalore    28        70
# 3   New_york    22        56
# 4    Chicago    18        59
# 5    Oralndo    26        78

# %%
con2 = pd.concat([india_wea,us_wea],keys=['india','US'])
con2
# Out:
#               city  Temp  Humidity
# india 0        Hyd    32        80
#       1    Chennai    40        60
#       2  Bangalore    28        70
# US    0   New_york    22        56
#       1    Chicago    18        59
#       2    Oralndo    26        78

# %%
con2.loc['india']
# Out:
#         city  Temp  Humidity
# 0        Hyd    32        80
# 1    Chennai    40        60
# 2  Bangalore    28        70

# %%
joinn = india_wea = pd.DataFrame({
    'city':['Hyd','Chennai','Bangalore'],
    'Temp':[32,40,28]
    
    
})

# %%
join1 = pd.DataFrame({
    'city':['Hyd','Chennai','Bangalore','Pakala'],
    'Humidity':[80,60,70,94]
    
})

# %%
joinn
# Out:
#         city  Temp
# 0        Hyd    32
# 1    Chennai    40
# 2  Bangalore    28

# %%
join1
# Out:
#         city  Humidity
# 0        Hyd        80
# 1    Chennai        60
# 2  Bangalore        70

# %%
pd.merge(joinn,join1,on='city')
# Out:
#         city  Temp  Humidity
# 0        Hyd    32        80
# 1    Chennai    40        60
# 2  Bangalore    28        70

# %%
pd.merge(joinn,join1,on='city',how='outer')
# Out:
#         city  Temp  Humidity
# 0        Hyd  32.0        80
# 1    Chennai  40.0        60
# 2  Bangalore  28.0        70
# 3     Pakala   NaN        94

# %%
pd.merge(joinn,join1,on='city',how='inner')
# Out:
#         city  Temp  Humidity
# 0        Hyd    32        80
# 1    Chennai    40        60
# 2  Bangalore    28        70

# %% [markdown]
# ## Pivot table

# %%
piv = pd.read_csv(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\SOURCE\CODE_Basics\7weather.csv')
piv
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
piv.pivot(index='date',columns='city')
# Out:
#          temperature                 humidity
# city         beijing mumbai new york  beijing mumbai new york
# date
# 5/1/2017          80     75       65       26     80       56
# 5/2/2017          77     78       66       30     83       58
# 5/3/2017          79     82       68       35     85       60

# %%
piv.pivot(index='date',columns='city',values='humidity')
# Out:
# city      beijing  mumbai  new york
# date
# 5/1/2017       26      80        56
# 5/2/2017       30      83        58
# 5/3/2017       35      85        60

# %% [markdown]
# ##### Pivot table will summarize and aggregate data inside the dataframe

# %%
piv_tab = piv = pd.read_csv(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\SOURCE\CODE_Basics\7weather2.csv')
piv_tab
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/1/2017  new york           61        54
# 2  5/2/2017  new york           70        60
# 3  5/2/2017  new york           72        62
# 4  5/1/2017    mumbai           75        80
# 5  5/1/2017    mumbai           78        83
# 6  5/2/2017    mumbai           82        85
# 7  5/2/2017    mumbai           80        26

# %%
piv_tab.pivot_table(index='date',columns='city')
# Out:
#          humidity          temperature
# city       mumbai new york      mumbai new york
# date
# 5/1/2017     81.5     55.0        76.5     63.0
# 5/2/2017     55.5     61.0        81.0     71.0

# %%
# by default the mean is the aggregate function
piv_tab.pivot_table(index='date',columns='city',aggfunc='sum')
# Out:
#          humidity          temperature
# city       mumbai new york      mumbai new york
# date
# 5/1/2017      163      110         153      126
# 5/2/2017      111      122         162      142

# %%
## Margins will add another column with aggregation
piv_tab.pivot_table(index='date',columns='city',margins=True)
# Out:
#          humidity                 temperature
# city       mumbai new york    All      mumbai new york     All
# date
# 5/1/2017     81.5     55.0  68.25       76.50     63.0  69.750
# 5/2/2017     55.5     61.0  58.25       81.00     71.0  76.000
# All          68.5     58.0  63.25       78.75     67.0  72.875

# %%
piv_tab1 = piv = pd.read_csv(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\SOURCE\CODE_Basics\7weather3.csv',
                             parse_dates=['date'])
piv_tab1
# Out:
#         date      city  temperature  humidity
# 0 2017-05-01  new york           65        56
# 1 2017-05-02  new york           61        54
# 2 2017-05-03  new york           70        60
# 3 2017-12-01  new york           30        50
# 4 2017-12-02  new york           28        52
# 5 2017-12-03  new york           25        51

# %%
# parsing date
piv_tab1 = piv = pd.read_csv(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\SOURCE\CODE_Basics\7weather3.csv')
piv_tab1['date'] = pd.to_datetime(piv_tab1['date'])
piv_tab1
# Out:
#         date      city  temperature  humidity
# 0 2017-05-01  new york           65        56
# 1 2017-05-02  new york           61        54
# 2 2017-05-03  new york           70        60
# 3 2017-12-01  new york           30        50
# 4 2017-12-02  new york           28        52
# 5 2017-12-03  new york           25        51

# %%
type(piv_tab1['date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
## average temp in the month of may and december

piv_tab1.pivot_table(index=pd.Grouper(freq='M',key='date'),columns='city')
# Out:
#              humidity temperature
# city         new york    new york
# date
# 2017-05-31  56.666667   65.333333
# 2017-12-31  51.000000   27.666667

# %% [markdown]
# ### Melt function
# #####  It is used to transform or reshape the data

# %%
mel = piv = pd.read_csv(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\SOURCE\CODE_Basics\8weather_reshape.csv')
mel
# Out:
#          day  chicago  chennai  berlin
# 0     Monday       32       75      41
# 1    Tuesday       30       77      43
# 2  Wednesday       28       75      45
# 3   Thursday       22       82      38
# 4     Friday       30       83      30
# 5   Saturday       20       81      45
# 6     Sunday       25       77      47

# %%
mel1= pd.melt(mel,id_vars=['day'])

# %%
mel1.loc[mel1['day']=='Monday']
# Out:
#        day variable  value
# 0   Monday  chicago     32
# 7   Monday  chennai     75
# 14  Monday   berlin     41

# %%
## changing the column names
mel1=pd.melt(mel,id_vars=['day'],var_name='City',value_name='Temparature')
mel1
# Out:
#           day     City  Temparature
# 0      Monday  chicago           32
# 1     Tuesday  chicago           30
# 2   Wednesday  chicago           28
# 3    Thursday  chicago           22
# 4      Friday  chicago           30
# 5    Saturday  chicago           20
# 6      Sunday  chicago           25
# 7      Monday  chennai           75
# 8     Tuesday  chennai           77
# 9   Wednesday  chennai           75
# 10   Thursday  chennai           82
# 11     Friday  chennai           83
# 12   Saturday  chennai           81
# 13     Sunday  chennai           77
# 14     Monday   berlin           41
# 15    Tuesday   berlin           43
# 16  Wednesday   berlin           45
# 17   Thursday   berlin           38
# 18     Friday   berlin           30
# 19   Saturday   berlin           45
# 20     Sunday   berlin           47

# %% [markdown]
# ## Stack and unstack

# %%
stac = pd.read_excel(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\SOURCE\CODE_Basics\9stocks.xlsx',header=[0,1])
stac
# Out:
#   Unnamed: 0_level_0    Price                  Price to earnings ratio (P/E)  \
#              Company Facebook Google Microsoft                      Facebook
# 0         2017-06-05      155    955        66                         37.10
# 1         2017-06-06      150    987        69                         36.98
# 2         2017-06-07      153    963        62                         36.78
# 3         2017-06-08      155   1000        61                         36.11
# 4         2017-06-09      156   1012        66                         37.07
#
#
#   Google Microsoft
# 0   32.0     30.31
# 1   31.3     30.56
# 2   31.7     30.46
# 3   31.2     30.11
# 4   30.0     31.00

# %%
stac.stack()
# Out:
#               Price  Price to earnings ratio (P/E) Unnamed: 0_level_0
# 0 Company       NaN                            NaN         2017-06-05
#   Facebook    155.0                          37.10                NaT
#   Google      955.0                          32.00                NaT
#   Microsoft    66.0                          30.31                NaT
# 1 Company       NaN                            NaN         2017-06-06
#   Facebook    150.0                          36.98                NaT
#   Google      987.0                          31.30                NaT
#   Microsoft    69.0                          30.56                NaT
# 2 Company       NaN                            NaN         2017-06-07
#   Facebook    153.0                          36.78                NaT
#   Google      963.0                          31.70                NaT
#   Microsoft    62.0                          30.46                NaT
# ...

# %%
stacked = stac.stack(level=0)

# %%
stacked.unstack()
# Out:
#   Company                                                  Facebook  \
#     Price Price to earnings ratio (P/E) Unnamed: 0_level_0    Price
# 0     NaT                           NaT         2017-06-05    155.0
# 1     NaT                           NaT         2017-06-06    150.0
# 2     NaT                           NaT         2017-06-07    153.0
# 3     NaT                           NaT         2017-06-08    155.0
# 4     NaT                           NaT         2017-06-09    156.0
#
#                                                     Google  \
#   Price to earnings ratio (P/E) Unnamed: 0_level_0   Price
# 0                         37.10                NaN   955.0
# 1                         36.98                NaN   987.0
# 2                         36.78                NaN   963.0
# 3                         36.11                NaN  1000.0
# 4                         37.07                NaN  1012.0
#
#                                                    Microsoft  \
# ...

# %%
stac = pd.read_excel(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\SOURCE\CODE_Basics\9stocks_3_levels.xlsx',
                    header=[0,1,2])
stac
# Out:
#   Unnamed: 0_level_0 Price Ratios                   \
#   Unnamed: 0_level_1        Price
#              Company     Facebook Google Microsoft
# 0            Q1 2016          155    955        66
# 1            Q2 2016          150    987        69
# 2            Q3 2016          153    963        62
# 3            Q4 2016          155   1000        61
# 4            Q1 2017          156   1012        66
#
#                                                  Income Statement         \
#   Price to earnings ratio (P/E)                         Net Sales
#                        Facebook Google Microsoft         Facebook Google
# 0                         37.10   32.0     30.31              2.6     20
# 1                         36.98   31.3     30.56              3.1     22
# 2                         36.78   31.7     30.46              4.3     24
# 3                         36.11   31.2     30.11              6.7     26
# ...

# %%
stac.stack(level=1)
# Out:
#                                 Income Statement                   \
#                                         Facebook Google Microsoft
# 0 Net Profit                                0.80   5.43      4.56
#   Net Sales                                 2.60  20.00     18.70
#   Price                                      NaN    NaN       NaN
#   Price to earnings ratio (P/E)              NaN    NaN       NaN
#   Unnamed: 0_level_1                         NaN    NaN       NaN
# 1 Net Profit                                0.97   5.89      5.10
#   Net Sales                                 3.10  22.00     21.30
#   Price                                      NaN    NaN       NaN
#   Price to earnings ratio (P/E)              NaN    NaN       NaN
#   Unnamed: 0_level_1                         NaN    NaN       NaN
# 2 Net Profit                                1.20   6.10      5.43
#   Net Sales                                 4.30  24.00     21.45
# ...

# %% [markdown]
# ## Cross table

# %%
crs = pd.read_csv(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\SOURCE\CODE_Basics\10survey.csv')
crs
# Out:
#       Name Nationality     Sex  Age Handedness
# 0    Kathy         USA  Female   23      Right
# 1    Linda         USA  Female   18      Right
# 2    Peter         USA    Male   19      Right
# 3     John         USA    Male   22       Left
# 4   Fatima   Bangadesh  Female   31       Left
# 5    Kadir   Bangadesh    Male   25       Left
# 6   Dhaval       India    Male   35       Left
# 7   Sudhir       India    Male   31       Left
# 8   Parvir       India    Male   37      Right
# 9      Yan       China  Female   52      Right
# 10    Juan       China  Female   58       Left
# 11   Liang       China    Male   43       Left

# %%
pd.crosstab(crs.Nationality,crs.Handedness)
# Out:
# Handedness   Left  Right
# Nationality
# Bangadesh       2      0
# China           2      1
# India           2      1
# USA             1      3

# %%
pd.crosstab([crs.Nationality,crs.Sex],[crs.Handedness], margins=True)
# Out:
# Handedness          Left  Right  All
# Nationality Sex
# Bangadesh   Female     1      0    1
#             Male       1      0    1
# China       Female     1      1    2
#             Male       1      0    1
# India       Male       2      1    3
# USA         Female     0      2    2
#             Male       1      1    2
# All                    7      5   12

# %%
pd.crosstab(crs.Sex,[crs.Handedness,crs.Nationality],margins=True)
# Out:
# Handedness       Left                 Right           All
# Nationality Bangadesh China India USA China India USA
# Sex
# Female              1     1     0   0     1     0   2   5
# Male                1     1     2   1     0     1   1   7
# All                 2     2     2   1     1     1   3  12

# %% [markdown]
# # Shift + tab will open the documentation

# %%
pd.crosstab([crs.Sex],[crs.Handedness], margins=True)
# Out:
# Handedness  Left  Right  All
# Sex
# Female         2      3    5
# Male           5      2    7
# All            7      5   12

# %%
pd.crosstab([crs.Sex],[crs.Handedness], normalize='index')
# Out:
# Handedness      Left     Right
# Sex
# Female      0.400000  0.600000
# Male        0.714286  0.285714

# %%
import numpy as np
pd.crosstab([crs.Sex],[crs.Handedness], values=crs.Age,aggfunc=np.average)
# Out:
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:393: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\Anaconda3\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Handedness  Left  Right
# Sex
# Female      44.5   31.0
# Male        31.2   28.0

# %% [markdown]
# # Time Series
#
# ######  Time series is a set of data points indexed in time order

# %%
ts = pd.read_csv(r"C:\Users\Lenovo\Desktop\Data_Science\Inceptez\SOURCE\CODE_Basics\10aapl.csv",parse_dates=['Date'])
ts.head(2)
# Out:
#         Date    Open    High     Low   Close    Volume
# 0 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 1 2017-07-06  143.02  143.50  142.41  142.73  24128782

# %% [markdown]
# ## Datatimeindex

# %%
type(ts.Date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
ts.set_index('Date',inplace=True)

# %%
ts.head(3)
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557

# %%
ts.index.min()
# Out:
# Timestamp('2016-07-11 00:00:00')

# %%
ts.index.max()
# Out:
# Timestamp('2017-07-07 00:00:00')

# %%
ts['2017-06-01']
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-06-01  153.17  153.33  152.22  153.18  16404088

# %%
ts['2017-06'].Close.mean()
# Out:
# 147.8313636363636

# %%
ts['2017-06'].head(2)
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-06-30  144.45  144.96  143.78  144.02  23024107
# 2017-06-29  144.71  145.13  142.28  143.68  31499368

# %%
ts['2016-05':'2017-07']
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Volume]
# Index: []

# %% [markdown]
# # Resampling

# %%
ts.Close
# Out:
# Date
# 2017-07-07    144.18
# 2017-07-06    142.73
# 2017-07-05    144.09
# 2017-07-03    143.50
# 2017-06-30    144.02
#                ...
# 2016-07-15     98.78
# 2016-07-14     98.79
# 2016-07-13     96.87
# 2016-07-12     97.42
# 2016-07-11     96.98
# Name: Close, Length: 251, dtype: float64

# %%
# getting each column montly aggregation
ts.Close.resample('M').sum()
# Out:
# Date
# 2016-07-31    1492.10
# 2016-08-31    2476.30
# 2016-09-30    2328.00
# 2016-10-31    2429.85
# 2016-11-30    2313.24
# 2016-12-31    2401.05
# 2017-01-31    2391.40
# 2017-02-28    2540.56
# 2017-03-31    3234.21
# 2017-04-30    2714.85
# 2017-05-31    3349.01
# 2017-06-30    3252.29
# 2017-07-31     574.50
# Freq: M, Name: Close, dtype: float64

# %%
# %matplotlib inline
ts.Close.resample('M').mean().plot()

# %%
ts.Close.resample('Q').mean().plot(kind='bar')

# %%
ts.Close.plot()

# %% [markdown]
# # Date Range

# %%
# Generating dates
dr = pd.read_csv(r"C:\Users\Lenovo\Desktop\Data_Science\Inceptez\SOURCE\CODE_Basics\11aapl_no_dates.csv")
dr.head(2)
# Out:
#      Open    High     Low   Close    Volume
# 0  153.17  153.33  152.22  153.18  16404088
# 1  153.58  155.45  152.89  155.45  27770715

# %%
#freq ---> Business-days
rng = pd.date_range(start='6/1/2017',end='6/30/2017',freq='B')

# %%
rng
# Out:
# DatetimeIndex(['2017-06-01', '2017-06-02', '2017-06-05', '2017-06-06',
#                '2017-06-07', '2017-06-08', '2017-06-09', '2017-06-12',
#                '2017-06-13', '2017-06-14', '2017-06-15', '2017-06-16',
#                '2017-06-19', '2017-06-20', '2017-06-21', '2017-06-22',
#                '2017-06-23', '2017-06-26', '2017-06-27', '2017-06-28',
#                '2017-06-29', '2017-06-30'],
#               dtype='datetime64[ns]', freq='B')

# %%
dr.set_index(rng,inplace=True)

# %%
dr
# Out:
#               Open    High     Low   Close    Volume
# 2017-06-01  153.17  153.33  152.22  153.18  16404088
# 2017-06-02  153.58  155.45  152.89  155.45  27770715
# 2017-06-05  154.34  154.45  153.46  153.93  25331662
# 2017-06-06  153.90  155.81  153.78  154.45  26624926
# 2017-06-07  155.02  155.98  154.48  155.37  21069647
# 2017-06-08  155.25  155.54  154.40  154.99  21250798
# 2017-06-09  155.19  155.19  146.02  148.98  64882657
# 2017-06-12  145.74  146.09  142.51  145.42  72307330
# 2017-06-13  147.16  147.45  145.15  146.59  34165445
# 2017-06-14  147.50  147.50  143.84  145.16  31531232
# 2017-06-15  143.32  144.48  142.21  144.29  32165373
# 2017-06-16  143.78  144.50  142.20  142.27  50361093
# 2017-06-19  143.66  146.74  143.66  146.34  32541404
# 2017-06-20  146.87  146.87  144.94  145.01  24900073
# 2017-06-21  145.52  146.07  144.61  145.87  21265751
# 2017-06-22  145.77  146.70  145.12  145.63  19106294
# 2017-06-23  145.13  147.16  145.11  146.28  35439389
# ...

# %%
# %matplotlib inline
dr.Close.plot()

# %%
dr["2017-06-01":"2017-06-10"].Close.sum()
# Out:
# 1076.35

# %%
dr.asfreq('D',method='pad')
# Out:
#               Open    High     Low   Close    Volume
# 2017-06-01  153.17  153.33  152.22  153.18  16404088
# 2017-06-02  153.58  155.45  152.89  155.45  27770715
# 2017-06-03  153.58  155.45  152.89  155.45  27770715
# 2017-06-04  153.58  155.45  152.89  155.45  27770715
# 2017-06-05  154.34  154.45  153.46  153.93  25331662
# 2017-06-06  153.90  155.81  153.78  154.45  26624926
# 2017-06-07  155.02  155.98  154.48  155.37  21069647
# 2017-06-08  155.25  155.54  154.40  154.99  21250798
# 2017-06-09  155.19  155.19  146.02  148.98  64882657
# 2017-06-10  155.19  155.19  146.02  148.98  64882657
# 2017-06-11  155.19  155.19  146.02  148.98  64882657
# 2017-06-12  145.74  146.09  142.51  145.42  72307330
# 2017-06-13  147.16  147.45  145.15  146.59  34165445
# 2017-06-14  147.50  147.50  143.84  145.16  31531232
# 2017-06-15  143.32  144.48  142.21  144.29  32165373
# 2017-06-16  143.78  144.50  142.20  142.27  50361093
# 2017-06-17  143.78  144.50  142.20  142.27  50361093
# ...

# %%
dr.asfreq('W',method='pad')
# Out:
#               Open    High     Low   Close    Volume
# 2017-06-04  153.58  155.45  152.89  155.45  27770715
# 2017-06-11  155.19  155.19  146.02  148.98  64882657
# 2017-06-18  143.78  144.50  142.20  142.27  50361093
# 2017-06-25  145.13  147.16  145.11  146.28  35439389

# %%
dr.asfreq('H',method='pad')
# Out:
#                        Open    High     Low   Close    Volume
# 2017-06-01 00:00:00  153.17  153.33  152.22  153.18  16404088
# 2017-06-01 01:00:00  153.17  153.33  152.22  153.18  16404088
# 2017-06-01 02:00:00  153.17  153.33  152.22  153.18  16404088
# 2017-06-01 03:00:00  153.17  153.33  152.22  153.18  16404088
# 2017-06-01 04:00:00  153.17  153.33  152.22  153.18  16404088
# ...                     ...     ...     ...     ...       ...
# 2017-06-29 20:00:00  144.71  145.13  142.28  143.68  31499368
# 2017-06-29 21:00:00  144.71  145.13  142.28  143.68  31499368
# 2017-06-29 22:00:00  144.71  145.13  142.28  143.68  31499368
# 2017-06-29 23:00:00  144.71  145.13  142.28  143.68  31499368
# 2017-06-30 00:00:00  144.45  144.96  143.78  144.02  23024107
#
# [697 rows x 5 columns]

# %%
rng1 = pd.date_range(start='1/1/2017',periods=72,freq='B')
rng
# Out:
# DatetimeIndex(['2017-06-01', '2017-06-02', '2017-06-05', '2017-06-06',
#                '2017-06-07', '2017-06-08', '2017-06-09', '2017-06-12',
#                '2017-06-13', '2017-06-14', '2017-06-15', '2017-06-16',
#                '2017-06-19', '2017-06-20', '2017-06-21', '2017-06-22',
#                '2017-06-23', '2017-06-26', '2017-06-27', '2017-06-28',
#                '2017-06-29', '2017-06-30'],
#               dtype='datetime64[ns]', freq='B')

# %%
import numpy as np
np.random.randint(1,10,len(rng1))
# Out:
# array([6, 5, 1, 8, 7, 1, 4, 9, 5, 2, 4, 2, 3, 5, 6, 5, 3, 8, 5, 1, 1, 4,
#        4, 4, 8, 2, 4, 5, 7, 4, 8, 9, 7, 9, 6, 4, 2, 8, 2, 3, 4, 8, 9, 1,
#        5, 4, 6, 9, 5, 1, 3, 3, 2, 9, 8, 4, 9, 7, 7, 7, 6, 2, 6, 1, 2, 3,
#        7, 1, 5, 8, 5, 5])

# %%
ts = pd.Series(np.random.randint(1,10,len(rng1)),index=rng1)

# %%
### Date range will not handle holidays by default

# %%
pd.date_range(start='7/1/2017',end='7/21/2017',freq='B')
# Out:
# DatetimeIndex(['2017-07-03', '2017-07-04', '2017-07-05', '2017-07-06',
#                '2017-07-07', '2017-07-10', '2017-07-11', '2017-07-12',
#                '2017-07-13', '2017-07-14', '2017-07-17', '2017-07-18',
#                '2017-07-19', '2017-07-20', '2017-07-21'],
#               dtype='datetime64[ns]', freq='B')

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay

# %%
usb = CustomBusinessDay(calendar = USFederalHolidayCalendar())
usb

# %%
rng3 = pd.date_range(start='7/1/2017',end='7/21/2017',freq=usb)

# %%
dr.set_index(rng3,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-145-c9cbc4811cf3> in <module>
# ----> 1 dr.set_index(rng3,inplace=True)
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4345                 # ensure_index_from_sequences would not raise for append=False.
#    4346                 raise ValueError(
# -> 4347                     f"Length mismatch: Expected {len(self)} rows, "
#    4348                     f"received array of length {len(arrays[-1])}"
#    4349                 )
#
# ValueError: Length mismatch: Expected 22 rows, received array of length 14

# %% [markdown]
# ## to_datetime

# %%
import pandas as pd
dates = ['2017-01-05 2:30 PM','Jan 5 2017','01/05/2017 14:30','2017.01.05','2017/01/05','20170105']

# %%
pd.to_datetime(dates)
# Out:
# DatetimeIndex(['2017-01-05 14:30:00', '2017-01-05 00:00:00',
#                '2017-01-05 14:30:00', '2017-01-05 00:00:00',
#                '2017-01-05 00:00:00', '2017-01-05 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
## Us ---> mm/dd/yyyy
## UK ---> dd/mm/yyyy

# %%
pd.to_datetime('1/5/2017')
# Out:
# Timestamp('2017-01-05 00:00:00')

# %%
pd.to_datetime('1/5/2017',dayfirst=True)
# Out:
# Timestamp('2017-05-01 00:00:00')

# %%
pd.to_datetime('5$1$2017',format='%d$%m$%Y')
# Out:
# Timestamp('2017-01-05 00:00:00')

# %%
dates_error = ['2017-01-05 2:30 PM','Jan 5 2017','01/05/2017 14:30','2017.01.05','2017/01/05','20170105','abc']
pd.to_datetime(dates_error,errors = 'ignore')
# Out:
# Index(['2017-01-05 2:30 PM', 'Jan 5 2017', '01/05/2017 14:30', '2017.01.05',
#        '2017/01/05', '20170105', 'abc'],
#       dtype='object')

# %%
pd.to_datetime(dates_error,errors = 'coerce')
# Out:
# DatetimeIndex(['2017-01-05 14:30:00', '2017-01-05 00:00:00',
#                '2017-01-05 14:30:00', '2017-01-05 00:00:00',
#                '2017-01-05 00:00:00', '2017-01-05 00:00:00',
#                                'NaT'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ## UNIX EPOCTIME

# %%
t = 1609157710
pd.to_datetime(t,unit='s')
# Out:
# Timestamp('2020-12-28 12:15:10')

# %%
dt = pd.to_datetime([t],unit='s')
dt
# Out:
# DatetimeIndex(['2020-12-28 12:15:10'], dtype='datetime64[ns]', freq=None)

# %%
dt.view('int64')
# Out:
# array([1609157710000000000], dtype=int64)

# %%
y = pd.Period('2016')
y
# Out:
# Period('2016', 'A-DEC')

# %% [raw]
# dir(y)

# %%
y.start_time
# Out:
# Timestamp('2016-01-01 00:00:00')

# %%
y.end_time
# Out:
# Timestamp('2016-12-31 23:59:59.999999999')

# %%
m = pd.Period('2011-1',freq='M')
m
# Out:
# Period('2011-01', 'M')

# %%
m.start_time
# Out:
# Timestamp('2011-01-01 00:00:00')

# %%
m.end_time
# Out:
# Timestamp('2011-01-31 23:59:59.999999999')

# %%
m+1
# Out:
# Period('2011-02', 'M')

# %%
d = pd.Period('2016-02-28',freq='D')
d
# Out:
# Period('2016-02-28', 'D')

# %%
d+1
# Out:
# Period('2016-02-29', 'D')

# %%
i = 1 
while True: 
    if i%3 == 0: 
        break
    print(i) 
    i += 1
# Out:
# 1
# 2

# %%
i = 1 
while True: 
    if i%2 == 0: 
        break 
        print(i) 
        i += 2
