# %% [markdown]
# # Seaborn

# %% [markdown]
# #### Bulit on top of matplotlib. It provides high level for drawing attractive and informative statitical information

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\SOURCE\DATA_FOR_DATAVIS\fifa.csv',index_col='Date',
                 parse_dates=True)

# %%
df.head(3)
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0

# %%
df.dtypes
# Out:
# ARG    float64
# BRA    float64
# ESP    float64
# FRA    float64
# GER    float64
# ITA    float64
# dtype: object

# %% [markdown]
# ## Line plot

# %%
sns.lineplot(data=df)

# %%
plt.figure(figsize=(16,6))
#plt.xticks([1996,2000,2004,2008,2012])
sns.lineplot(data=df)

# %% [markdown]
# ## Step
# 1. Loading the data
# 2.Examine the data and understand what to show
# 3.Plottng the data

# %%
spotify_data=pd.read_csv(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\SOURCE\DATA_FOR_DATAVIS\spotify.csv',index_col='Date',
                 parse_dates=True)

# %%
spotify_data.head(2)
# Out:
#             Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN      NaN
# 2017-01-07      13190270        NaN                       NaN      NaN
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# 2017-01-07            NaN

# %%
spotify_data.isna().sum()
# Out:
# Shape of You                 0
# Despacito                    7
# Something Just Like This    47
# HUMBLE.                     84
# Unforgettable               91
# dtype: int64

# %%
spotify_data.tail()
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2018-01-05      2869783.0
# 2018-01-06      2743748.0
# 2018-01-07      2441045.0
# 2018-01-08      2622693.0
# 2018-01-09      2627334.0

# %%
sns.lineplot(data=spotify_data)

# %%
plt.figure(figsize=(16,6))
plt.title('Popular Song Streams from 2017 - 2018')
sns.lineplot(data=spotify_data['Shape of You'],label='SOY')
sns.lineplot(data=spotify_data['Despacito'],label='Desp')
sns.lineplot(data=spotify_data['Something Just Like This'],label='SJL')
plt.xlabel('Dates from 2017-2018')
# Out:
# Text(0.5, 0, 'Dates from 2017-2018')

# %%
plt.figure(figsize=(16,6))
sns.lineplot(data=spotify_data['Something Just Like This'],label='SJLT')
sns.lineplot(data=spotify_data['HUMBLE.'],label='Humble')
plt.xlabel('Dates from 2017-2018')
# Out:
# Text(0.5, 0, 'Dates from 2017-2018')

# %%
sns.__version__
# Out:
# '0.10.0'

# %%
#!pip install seaborn

# %% [markdown]
# ## Bar plot  ---> Used when need to visulaize relationship

# %%
flight_delay=pd.read_csv(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\SOURCE\DATA_FOR_DATAVIS\flight_delays.csv',
                 parse_dates=True)
flight_delay.head(2)
# Out:
#    Month        AA        AS         B6        DL         EV         F9  \
# 0      1  6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 1      2  7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
#
#          HA         MQ         NK         OO        UA        US        VX  \
# 0  3.512640  18.164974  11.398054  10.889894  6.352729  3.107457  1.420702
# 1  6.029967  21.301627  16.474466   9.588895  7.260662  7.114455  7.784410
#
#          WN
# 0  3.389466
# 1  3.501363

# %%
plt.figure(figsize=(16,6))
plt.title(label='Flight Delay Details')
sns.barplot(x=flight_delay['Month'],y=flight_delay['NK'],label='NKK')

# %% [markdown]
# ## Best once to use

# %%
plt.figure(figsize=(16,6))
plt.title("Flight Delays")
sns.barplot(data=flight_delay,x="Month",y="NK")
plt.xlabel("Month")
plt.ylabel("Flight Name")
# Out:
# Text(0, 0.5, 'Flight Name')

# %%
# Heatmap
plt.figure(figsize=(16,6))
plt.title("Flight Delays")
sns.heatmap(data=flight_delay)

# %%
corr = flight_delay.corr()

# %% [markdown]
# # Scatter plot

# %%
insurance_data = pd.read_csv(r'C:\Users\Lenovo\Desktop\Data_Science\Inceptez\SOURCE\DATA_FOR_DATAVIS\insurance.csv')
insurance_data.head(2)
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523

# %%
sns.scatterplot(x=insurance_data['bmi'],y=insurance_data['charges'])

# %%
sns.scatterplot(x=insurance_data['bmi'],y=insurance_data['charges'],hue=insurance_data['smoker'])

# %%
sns.scatterplot(x=insurance_data['bmi'],y=insurance_data['charges'],hue=insurance_data['age'])

# %%
sns.scatterplot(x=insurance_data['age'],y=insurance_data['charges'],hue=insurance_data['children'])

# %%
sns.catplot(data=insurance_data,x='region',y='charges',hue='smoker',kind='bar')

# %% [markdown]
# # Swam plot

# %%
sns.swarmplot(x=insurance_data['smoker'],y=insurance_data['charges'])

# %%
sns.swarmplot(x=insurance_data['smoker'],y=insurance_data['age'])

# %%
# regplot  ---> relaeted to best fit line

# %%
sns.regplot(x=insurance_data['bmi'],y=insurance_data['charges'])

# %%
sns.lmplot(x='bmi',y='charges',hue='smoker',data=insurance_data)
